# %%
# !nvidia-smi

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/All Project ML/yolov5
# Out:
# /content/drive/MyDrive/All Project ML/yolov5

# %%
# !git clone "http://github.com/ultralytics/yolov5" '/content/drive/MyDrive/All Project ML/yolov5/yolov5'
# Out:
# fatal: destination path '/content/drive/MyDrive/All Project ML/yolov5/yolov5' already exists and is not an empty directory.

# %%
# %cd /content/drive/MyDrive/All Project ML/yolov5/yolov5
# Out:
# /content/drive/MyDrive/All Project ML/yolov5/yolov5

# %%
# !pip install -r requirements.txt

# %%
# %cd /content/drive/MyDrive/All Project ML/yolov5
# Out:
# /content/drive/MyDrive/All Project ML/yolov5

# %%
# !unzip '/content/drive/MyDrive/All Project ML/yolov5/images.zip' -d '/content/drive/MyDrive/All Project ML/yolov5/train_data'

# %%
# Tổ chức lại thư mục
# train
#    - images
#    - labels
# test
#    - images
#    - labels

# %cd /content/drive/MyDrive/All Project ML/yolov5/train_data
# !mkdir train
# !mkdir train/images
# !mkdir train/labels
# !mv *.png train/images
# !mv *.txt train/labels
# Out:
# /content/drive/MyDrive/All Project ML/yolov5/train_data
# mkdir: cannot create directory ‘train’: File exists

# %%
# %cd /content/drive/MyDrive/All Project ML/yolov5/yolov5
#!rm data/mydataset.yaml
# !echo 'train: ../train_data/train' >> data/mydataset.yaml
# !echo 'val: ../train_data/train' >> data/mydataset.yaml
# !echo 'nc: 6' >> data/mydataset.yaml
# !echo "names: ['mau A', 'mau B (left)', 'mau C (right)', 'mau D', 'small', 'big']" >> data/mydataset.yaml
# Out:
# /content/drive/MyDrive/All Project ML/yolov5/yolov5

# %%
# !python train.py --img 640 --batch 16 --epochs 1000 --data data/mydataset.yaml --weights yolov5s.pt
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#       3/999      3.81G    0.07354    0.06089    0.02072         96        640: 100% 44/44 [00:05<00:00,  7.89it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 22/22 [00:05<00:00,  4.30it/s]
#                    all        692       7008      0.349      0.735      0.515       0.28
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/999      3.81G    0.06485    0.05812    0.01642         79        640: 100% 44/44 [00:05<00:00,  7.50it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 22/22 [00:05<00:00,  4.40it/s]
#                    all        692       7008      0.351      0.863      0.542      0.289
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
# ...
